# %%
print("hello")
# Out:
# hello

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# Requirement already satisfied: numpy>=2.3.3 in /Users/emilmareenap/ds_dsa/venv/lib/python3.14/site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/emilmareenap/ds_dsa/venv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/emilmareenap/ds_dsa/venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp314-cp314-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 11.2 MB/s  0:00:00 11.2 MB/s eta 0:00:01
# Installing collected packages: pandas
# Successfully installed pandas-3.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/emilmareenap/ds_dsa/venv/lib/python3.14/site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in /Users/emilmareenap/ds_dsa/venv/lib/python3.14/site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/emilmareenap/ds_dsa/venv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/emilmareenap/ds_dsa/venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data=pd.read_csv("tip.csv")

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#list operations

# %%
li=list()

# %%
type(li)
# Out:
# list

# %%
li.append(10)

# %%
li
# Out:
# [10]

# %%
li.append(2)

# %%
li.append(30)

# %%
li.append(23)

# %%
li
# Out:
# [10, 30, 23, 2, 2, 30, 23]

# %%
li.sort()

# %%
li
# Out:
# [2, 2, 10, 23, 23, 30, 30]

# %%
li.remove(2)

# %%
li
# Out:
# [2, 10, 23, 23, 30, 30]

# %%
li.remove(23)

# %%
li.remove(30)

# %%
li
# Out:
# [2, 10, 23, 30]

# %%
num=[2,5,1,10,8,23,21,11]

# %%
num
# Out:
# [2, 5, 1, 10, 8, 23, 21, 11]

# %%
nums=sorted(num)

# %%
nums
# Out:
# [1, 2, 5, 8, 10, 11, 21, 23]

# %%
names=['joe','mahek','abhi','ananya','rahul']

# %%
names
# Out:
# ['joe', 'mahek', 'abhi', 'ananya', 'rahul']

# %%
snames=sorted(names)

# %%
snames
# Out:
# ['abhi', 'ananya', 'joe', 'mahek', 'rahul']

# %%
# sort names based on  len

# %%
lnames=sorted(names,key=len,reverse=True)

# %%
lnames
# Out:
# ['ananya', 'mahek', 'rahul', 'abhi', 'joe']

# %%
lnum=[4**i for i in range(1,10)]

# %%
lnum
# Out:
# [4, 16, 64, 256, 1024, 4096, 16384, 65536, 262144]

# %%
lnum= [0]+[2**i for i in range(1,11)]

# %%
lnum
# Out:
# [0, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]

# %%
lnum=[(2*i)-1 for i in range(1,6)]

# %%
lnum
# Out:
# [1, 3, 5, 7, 9]

# %%
lnum=[ i for i in range(1,10) if i%2 != 0 ]

# %%
lnum
# Out:
# [1, 3, 5, 7, 9]

# %%
lm=[2,3,4,1,2,5,9]

# %%
lm
# Out:
# [2, 3, 4, 1, 2, 5, 9]

# %%
m=[]

# %%
for i in lm:
    if i not in m:
        m.append(i)

# %%
m
# Out:
# [2, 3, 4, 1, 5, 9]

# %%
m
# Out:
# [1, 2, 3, 4, 5, 9]

# %%
rm=[2,3,4,1,5,9]

# %%
rm
# Out:
# [2, 3, 4, 1, 5, 9]

# %%
print(rm[::-1])
# Out:
# [9, 5, 1, 4, 3, 2]

# %%
rm
# Out:
# [9, 5, 4, 3, 2, 1]

# %%
rm=[2,3,4,1,5,9]
target=int(input("target:"))
for i in rm:
    for j in rm:
        if i+j == target:
            print([i,j])
            break
    else:
        continue
    break
# Out:
# target: 5
# [2, 3]

# %%
d={'a':100,'b':200,'c':300}

# %%
d.get('a')
# Out:
# 100

# %%
d.get('d',0)
# Out:
# 0

# %%
d.popitem()
# Out:
# ('c', 300)

# %%
d.pop('a')
# Out:
# 100

# %%
d
# Out:
# {'b': 200}

# %%
emp={'id':1000,'name':'joe','salary':150000}

# %%
emp
# Out:
# {'id': 1000, 'name': 'joe', 'salary': 150000}

# %%
emp.get('id')
# Out:
# 1000

# %%
emp.setdefault('place','Goa')
# Out:
# 'Goa'

# %%
emp
# Out:
# {'id': 1000, 'name': 'joe', 'salary': 150000, 'place': 'Goa'}

# %%
emp.items()
# Out:
# dict_items([('id', 1000), ('name', 'joe'), ('salary', 150000), ('place', 'Goa')])

# %%
#()

# %%
t1=(1,2,3,4)

# %%
t1[0]=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[158], line 1
# ----> 1 t1[0]=1
#
# TypeError: 'tuple' object does not support item assignment

# %%
t2=([1,2,3],[2,4,5])

# %%
t2
# Out:
# ([1, 2, 3], [2, 4, 5])

# %%
t2[1][2]=3

# %%
t2
# Out:
# ([1, 2, 3], [2, 4, 3])

# %%
#set

# %%
s1={1,3,4,3,5}

# %%
s1
# Out:
# {1, 3, 4, 5}

# %%
l=[2,3,4,5,4,2,6]

# %%
ls=set(l)

# %%
ls
# Out:
# {2, 3, 4, 5, 6}

# %%
s1={1,3,4,5,3,3773,66,4444}

# %%
s1
# Out:
# {1, 3, 4, 5, 66, 3773, 4444}
